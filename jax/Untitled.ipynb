# %%
from transformers import AutoFeatureExtractor, ResNetForImageClassification
import torch
from datasets import load_dataset

# %%
model = ResNetForImageClassification.from_pretrained("microsoft/resnet-101")

# %%
import intel_extension_for_pytorch as ipex

# %%
ipex.optimize(model)
# Out:
# /home/sander/Desktop/jax/.venv/lib/python3.8/site-packages/intel_extension_for_pytorch/frontend.py:262: UserWarning: Conv BatchNorm folding failed during the optimize process.
#   warnings.warn("Conv BatchNorm folding failed during the optimize process.")
# ---------------------------------------------------------------------------
# TraceError                                Traceback (most recent call last)
# Cell In [4], line 1
# ----> 1 ipex.optimize(model)
#
# File ~/Desktop/jax/.venv/lib/python3.8/site-packages/intel_extension_for_pytorch/frontend.py:260, in optimize(model, dtype, optimizer, level, inplace, conv_bn_folding, weights_prepack, replace_dropout_with_identity, optimize_lstm, split_master_weight_for_bf16, fuse_update_step, auto_kernel_selection, sample_input)
#     258 if opt_properties.conv_bn_folding:
#     259     try:
# --> 260         optimized_model = optimization.fuse(optimized_model, inplace=inplace)
#     261     except:  # noqa E722
#     262         warnings.warn("Conv BatchNorm folding failed during the optimize process.")
#
# File ~/Desktop/jax/.venv/lib/python3.8/site-packages/torch/fx/experimental/optimization.py:60, in fuse(model, inplace)
#      58 if not inplace:
#      59     model = copy.deepcopy(model)
# ---> 60 fx_model = fx.symbolic_trace(model)
#      61 modules = dict(fx_model.named_modules())
#      62 new_graph = copy.deepcopy(fx_model.graph)
#
# File ~/Desktop/jax/.venv/lib/python3.8/site-packages/torch/fx/_symbolic_trace.py:878, in symbolic_trace(root, concrete_args)
#     830 """
#     831 Symbolic tracing API
#     832
#    (...)
#     875     GraphModule: a Module created from the recorded operations from ``root``.
#     876 """
#     877 tracer = Tracer()
# --> 878 graph = tracer.trace(root, concrete_args)
#     879 name = root.__class__.__name__ if isinstance(root, torch.nn.Module) else root.__name__
#     880 return GraphModule(tracer.root, graph, name)
#
# File ~/Desktop/jax/.venv/lib/python3.8/site-packages/torch/fx/_symbolic_trace.py:587, in Tracer.trace(self, root, concrete_args)
#     585     for module in self._autowrap_search:
#     586         _autowrap_check(patcher, module.__dict__, self._autowrap_function_ids)
# --> 587     self.create_node('output', 'output', (self.create_arg(fn(*args)),), {},
#     588                      type_expr=fn.__annotations__.get('return', None))
#     590 self.submodule_paths = None
#     592 return self.graph
#
# File ~/Desktop/jax/.venv/lib/python3.8/site-packages/transformers/models/resnet/modeling_resnet.py:385, in ResNetForImageClassification.forward(self, pixel_values, labels, output_hidden_states, return_dict)
#     378 r"""
#     379 labels (`torch.LongTensor` of shape `(batch_size,)`, *optional*):
#     380     Labels for computing the image classification/regression loss. Indices should be in `[0, ...,
#     381     config.num_labels - 1]`. If `config.num_labels > 1` a classification loss is computed (Cross-Entropy).
#     382 """
#     383 return_dict = return_dict if return_dict is not None else self.config.use_return_dict
# --> 385 outputs = self.resnet(pixel_values, output_hidden_states=output_hidden_states, return_dict=return_dict)
#     387 pooled_output = outputs.pooler_output if return_dict else outputs[1]
#     389 logits = self.classifier(pooled_output)
#
# File ~/Desktop/jax/.venv/lib/python3.8/site-packages/torch/fx/_symbolic_trace.py:577, in Tracer.trace.<locals>.module_call_wrapper(mod, *args, **kwargs)
#     573     return _orig_module_call(mod, *args, **kwargs)
#     575 _autowrap_check(patcher, getattr(getattr(mod, "forward", mod), "__globals__", {}),
#     576                 self._autowrap_function_ids)
# --> 577 return self.call_module(mod, forward, args, kwargs)
#
# File ~/Desktop/jax/.venv/lib/python3.8/site-packages/torch/fx/_symbolic_trace.py:372, in Tracer.call_module(self, m, forward, args, kwargs)
#     370 module_qualified_name = self.path_of_module(m)
#     371 if not self.is_leaf_module(m, module_qualified_name):
# --> 372     return forward(*args, **kwargs)
#     373 return self.create_proxy('call_module', module_qualified_name, args, kwargs)
#
# File ~/Desktop/jax/.venv/lib/python3.8/site-packages/torch/fx/_symbolic_trace.py:573, in Tracer.trace.<locals>.module_call_wrapper.<locals>.forward(*args, **kwargs)
#     572 def forward(*args, **kwargs):
# --> 573     return _orig_module_call(mod, *args, **kwargs)
#
# File ~/Desktop/jax/.venv/lib/python3.8/site-packages/torch/nn/modules/module.py:1130, in Module._call_impl(self, *input, **kwargs)
#    1126 # If we don't have any hooks, we want to skip the rest of the logic in
#    1127 # this function, and just call forward.
#    1128 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1129         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1130     return forward_call(*input, **kwargs)
#    1131 # Do not call functions when jit is used
#    1132 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~/Desktop/jax/.venv/lib/python3.8/site-packages/transformers/models/resnet/modeling_resnet.py:323, in ResNetModel.forward(self, pixel_values, output_hidden_states, return_dict)
#     318 output_hidden_states = (
#     319     output_hidden_states if output_hidden_states is not None else self.config.output_hidden_states
#     320 )
#     321 return_dict = return_dict if return_dict is not None else self.config.use_return_dict
# --> 323 embedding_output = self.embedder(pixel_values)
#     325 encoder_outputs = self.encoder(
#     326     embedding_output, output_hidden_states=output_hidden_states, return_dict=return_dict
#     327 )
#     329 last_hidden_state = encoder_outputs[0]
#
# File ~/Desktop/jax/.venv/lib/python3.8/site-packages/torch/fx/_symbolic_trace.py:577, in Tracer.trace.<locals>.module_call_wrapper(mod, *args, **kwargs)
#     573     return _orig_module_call(mod, *args, **kwargs)
#     575 _autowrap_check(patcher, getattr(getattr(mod, "forward", mod), "__globals__", {}),
#     576                 self._autowrap_function_ids)
# --> 577 return self.call_module(mod, forward, args, kwargs)
#
# File ~/Desktop/jax/.venv/lib/python3.8/site-packages/torch/fx/_symbolic_trace.py:372, in Tracer.call_module(self, m, forward, args, kwargs)
#     370 module_qualified_name = self.path_of_module(m)
#     371 if not self.is_leaf_module(m, module_qualified_name):
# --> 372     return forward(*args, **kwargs)
#     373 return self.create_proxy('call_module', module_qualified_name, args, kwargs)
#
# File ~/Desktop/jax/.venv/lib/python3.8/site-packages/torch/fx/_symbolic_trace.py:573, in Tracer.trace.<locals>.module_call_wrapper.<locals>.forward(*args, **kwargs)
#     572 def forward(*args, **kwargs):
# --> 573     return _orig_module_call(mod, *args, **kwargs)
#
# File ~/Desktop/jax/.venv/lib/python3.8/site-packages/torch/nn/modules/module.py:1130, in Module._call_impl(self, *input, **kwargs)
#    1126 # If we don't have any hooks, we want to skip the rest of the logic in
#    1127 # this function, and just call forward.
#    1128 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1129         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1130     return forward_call(*input, **kwargs)
#    1131 # Do not call functions when jit is used
#    1132 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~/Desktop/jax/.venv/lib/python3.8/site-packages/transformers/models/resnet/modeling_resnet.py:88, in ResNetEmbeddings.forward(self, pixel_values)
#      86 def forward(self, pixel_values: Tensor) -> Tensor:
#      87     num_channels = pixel_values.shape[1]
# ---> 88     if num_channels != self.num_channels:
#      89         raise ValueError(
#      90             "Make sure that the channel dimension of the pixel values match with the one set in the configuration."
#      91         )
#      92     embedding = self.embedder(pixel_values)
#
# File ~/Desktop/jax/.venv/lib/python3.8/site-packages/torch/fx/proxy.py:284, in Proxy.__bool__(self)
#     281             self.tracer.create_proxy('call_function', assert_fn, (self,), {})
#     282             return True
# --> 284 return self.tracer.to_bool(self)
#
# File ~/Desktop/jax/.venv/lib/python3.8/site-packages/torch/fx/proxy.py:160, in TracerBase.to_bool(self, obj)
#     153 @compatibility(is_backward_compatible=True)
#     154 def to_bool(self, obj: 'Proxy') -> bool:
#     155     """Called when a proxy object is being converted to a boolean, such as
#     156     when used in control flow.  Normally we don't know what to do because
#     157     we don't know the value of the proxy, but a custom tracer can attach more
#     158     information to the graph node using create_node and can choose to return a value.
#     159     """
# --> 160     raise TraceError('symbolically traced variables cannot be used as inputs to control flow')
#
# TraceError: symbolically traced variables cannot be used as inputs to control flow
